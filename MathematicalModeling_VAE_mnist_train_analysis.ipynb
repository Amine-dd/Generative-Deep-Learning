# %% [markdown]
# <a href="https://colab.research.google.com/github/Amine-dd/Generative-Deep-Learning/blob/master/MathematicalModeling_VAE_mnist_train_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %%
def load_mnist():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.astype('float32') / 255.
    x_train = x_train.reshape(x_train.shape + (1,))
    x_test = x_test.astype('float32') / 255.
    x_test = x_test.reshape(x_test.shape + (1,))

    return (x_train, y_train), (x_test, y_test)

# %%
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = load_mnist()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
from keras.callbacks import Callback, LearningRateScheduler
import numpy as np
import matplotlib.pyplot as plt
import os

#### CALLBACKS
class CustomCallback(Callback):
    
    def __init__(self, run_folder, print_every_n_batches, initial_epoch, vae):
        self.epoch = initial_epoch
        self.run_folder = run_folder
        self.print_every_n_batches = print_every_n_batches
        self.vae = vae

    def on_batch_end(self, batch, logs={}):  
        if batch % self.print_every_n_batches == 0:
            z_new = np.random.normal(size = (1,self.vae.z_dim))
            reconst = self.vae.decoder.predict(np.array(z_new))[0].squeeze()

            filepath = os.path.join(self.run_folder, 'images', 'img_' + str(self.epoch).zfill(3) + '_' + str(batch) + '.jpg')
            if len(reconst.shape) == 2:
                plt.imsave(filepath, reconst, cmap='gray_r')
            else:
                plt.imsave(filepath, reconst)

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch += 1



def step_decay_schedule(initial_lr, decay_factor=0.5, step_size=1):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        new_lr = initial_lr * (decay_factor ** np.floor(epoch/step_size))
        
        return new_lr

    return LearningRateScheduler(schedule)

# %%
from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint 
from keras.utils import plot_model

import numpy as np
import json
import os
import pickle


class VariationalAutoencoder():
    def __init__(self
        , input_dim
        , encoder_conv_filters
        , encoder_conv_kernel_size
        , encoder_conv_strides
        , decoder_conv_t_filters
        , decoder_conv_t_kernel_size
        , decoder_conv_t_strides
        , z_dim
        , use_batch_norm = False
        , use_dropout= False
        ):

        self.name = 'variational_autoencoder'

        self.input_dim = input_dim
        self.encoder_conv_filters = encoder_conv_filters
        self.encoder_conv_kernel_size = encoder_conv_kernel_size
        self.encoder_conv_strides = encoder_conv_strides
        self.decoder_conv_t_filters = decoder_conv_t_filters
        self.decoder_conv_t_kernel_size = decoder_conv_t_kernel_size
        self.decoder_conv_t_strides = decoder_conv_t_strides
        self.z_dim = z_dim

        self.use_batch_norm = use_batch_norm
        self.use_dropout = use_dropout

        self.n_layers_encoder = len(encoder_conv_filters)
        self.n_layers_decoder = len(decoder_conv_t_filters)

        self._build()

    def _build(self):
        
        ### THE ENCODER
        encoder_input = Input(shape=self.input_dim, name='encoder_input')

        x = encoder_input

        for i in range(self.n_layers_encoder):
            conv_layer = Conv2D(
                filters = self.encoder_conv_filters[i]
                , kernel_size = self.encoder_conv_kernel_size[i]
                , strides = self.encoder_conv_strides[i]
                , padding = 'same'
                , name = 'encoder_conv_' + str(i)
                )

            x = conv_layer(x)

            if self.use_batch_norm:
                x = BatchNormalization()(x)

            x = LeakyReLU()(x)

            if self.use_dropout:
                x = Dropout(rate = 0.25)(x)

        shape_before_flattening = K.int_shape(x)[1:]

        x = Flatten()(x)
        self.mu = Dense(self.z_dim, name='mu')(x)
        self.log_var = Dense(self.z_dim, name='log_var')(x)

        self.encoder_mu_log_var = Model(encoder_input, (self.mu, self.log_var))

        def sampling(args):
            mu, log_var = args
            epsilon = K.random_normal(shape=K.shape(mu), mean=0., stddev=1.)
            return mu + K.exp(log_var / 2) * epsilon

        encoder_output = Lambda(sampling, name='encoder_output')([self.mu, self.log_var])

        self.encoder = Model(encoder_input, encoder_output)
        
        

        ### THE DECODER

        decoder_input = Input(shape=(self.z_dim,), name='decoder_input')

        x = Dense(np.prod(shape_before_flattening))(decoder_input)
        x = Reshape(shape_before_flattening)(x)

        for i in range(self.n_layers_decoder):
            conv_t_layer = Conv2DTranspose(
                filters = self.decoder_conv_t_filters[i]
                , kernel_size = self.decoder_conv_t_kernel_size[i]
                , strides = self.decoder_conv_t_strides[i]
                , padding = 'same'
                , name = 'decoder_conv_t_' + str(i)
                )

            x = conv_t_layer(x)

            if i < self.n_layers_decoder - 1:
                if self.use_batch_norm:
                    x = BatchNormalization()(x)
                x = LeakyReLU()(x)
                if self.use_dropout:
                    x = Dropout(rate = 0.25)(x)
            else:
                x = Activation('sigmoid')(x)

            

        decoder_output = x

        self.decoder = Model(decoder_input, decoder_output)

        ### THE FULL VAE
        model_input = encoder_input
        model_output = self.decoder(encoder_output)

        self.model = Model(model_input, model_output)


    def compile(self, learning_rate, r_loss_factor):
        self.learning_rate = learning_rate

        ### COMPILATION
        def vae_r_loss(y_true, y_pred):
            r_loss = K.mean(K.square(y_true - y_pred), axis = [1,2,3])
            return r_loss_factor * r_loss

        def vae_kl_loss(y_true, y_pred):
            kl_loss =  -0.5 * K.sum(1 + self.log_var - K.square(self.mu) - K.exp(self.log_var), axis = 1)
            return kl_loss

        def vae_loss(y_true, y_pred):
            r_loss = vae_r_loss(y_true, y_pred)
            kl_loss = vae_kl_loss(y_true, y_pred)
            return  r_loss + kl_loss

        optimizer = Adam(lr=learning_rate)
        self.model.compile(optimizer=optimizer, loss = vae_loss,  metrics = [vae_r_loss, vae_kl_loss])


    def save(self, folder):

        if not os.path.exists(folder):
            os.makedirs(folder)
            os.makedirs(os.path.join(folder, 'viz'))
            os.makedirs(os.path.join(folder, 'weights'))
            os.makedirs(os.path.join(folder, 'images'))

        with open(os.path.join(folder, 'params.pkl'), 'wb') as f:
            pickle.dump([
                self.input_dim
                , self.encoder_conv_filters
                , self.encoder_conv_kernel_size
                , self.encoder_conv_strides
                , self.decoder_conv_t_filters
                , self.decoder_conv_t_kernel_size
                , self.decoder_conv_t_strides
                , self.z_dim
                , self.use_batch_norm
                , self.use_dropout
                ], f)

        self.plot_model(folder)


    def load_weights(self, filepath):
        self.model.load_weights(filepath)

    def train(self, x_train, batch_size, epochs, run_folder, print_every_n_batches = 100, initial_epoch = 0, lr_decay = 1):

        custom_callback = CustomCallback(run_folder, print_every_n_batches, initial_epoch, self)
        lr_sched = step_decay_schedule(initial_lr=self.learning_rate, decay_factor=lr_decay, step_size=1)
        
        checkpoint_filepath=os.path.join(run_folder, "weights/weights-{epoch:03d}-{loss:.2f}.h5")
        checkpoint1 = ModelCheckpoint(checkpoint_filepath, save_weights_only = True, verbose=1)
        checkpoint2 = ModelCheckpoint(os.path.join(run_folder, 'weights/weights.h5'), save_weights_only = True, verbose=1)

        callbacks_list = [checkpoint1, checkpoint2, custom_callback, lr_sched]

        self.model.fit(     
            x_train
            , x_train
            , batch_size = batch_size
            , shuffle = True
            , epochs = epochs
            , initial_epoch = initial_epoch
            , callbacks = callbacks_list
        )



    def train_with_generator(self, data_flow, epochs, steps_per_epoch, run_folder, print_every_n_batches = 100, initial_epoch = 0, lr_decay = 1, ):

        custom_callback = CustomCallback(run_folder, print_every_n_batches, initial_epoch, self)
        lr_sched = step_decay_schedule(initial_lr=self.learning_rate, decay_factor=lr_decay, step_size=1)

        checkpoint_filepath=os.path.join(run_folder, "weights/weights-{epoch:03d}-{loss:.2f}.h5")
        checkpoint1 = ModelCheckpoint(checkpoint_filepath, save_weights_only = True, verbose=1)
        checkpoint2 = ModelCheckpoint(os.path.join(run_folder, 'weights/weights.h5'), save_weights_only = True, verbose=1)

        callbacks_list = [checkpoint1, checkpoint2, custom_callback, lr_sched]

        self.model.save_weights(os.path.join(run_folder, 'weights/weights.h5'))
                
        self.model.fit_generator(
            data_flow
            , shuffle = True
            , epochs = epochs
            , initial_epoch = initial_epoch
            , callbacks = callbacks_list
            , steps_per_epoch=steps_per_epoch 
            )


    
    def plot_model(self, run_folder):
        plot_model(self.model, to_file=os.path.join(run_folder ,'viz/model.png'), show_shapes = True, show_layer_names = True)
        plot_model(self.encoder, to_file=os.path.join(run_folder ,'viz/encoder.png'), show_shapes = True, show_layer_names = True)
        plot_model(self.decoder, to_file=os.path.join(run_folder ,'viz/decoder.png'), show_shapes = True, show_layer_names = True)

# %%
vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
vae.encoder.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3136)         0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten_2[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten_2[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.encoder.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3136)         0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten_2[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten_2[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Training

# %%
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000

# %%
vae.compile(LEARNING_RATE, R_LOSS_FACTOR)

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 51.6966 - vae_r_loss: 47.7913 - vae_kl_loss: 3.9052
#
# Epoch 00001: saving model to run/vae/0002_digits/weights/weights-001-51.70.h5
#
# Epoch 00001: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 2/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 50.2953 - vae_r_loss: 46.0872 - vae_kl_loss: 4.2080
#
# Epoch 00002: saving model to run/vae/0002_digits/weights/weights-002-50.30.h5
#
# Epoch 00002: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 3/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 49.3323 - vae_r_loss: 44.9482 - vae_kl_loss: 4.3842
#
# Epoch 00003: saving model to run/vae/0002_digits/weights/weights-003-49.33.h5
#
# Epoch 00003: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 4/200
# 60000/60000 [==============================] - 16s 259us/step - loss: 48.7067 - vae_r_loss: 44.1729 - vae_kl_loss: 4.5338
#
# Epoch 00004: saving model to run/vae/0002_digits/weights/weights-004-48.71.h5
#
# Epoch 00004: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 5/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 48.1971 - vae_r_loss: 43.5558 - vae_kl_loss: 4.6413
#
# Epoch 00005: saving model to run/vae/0002_digits/weights/weights-005-48.20.h5
#
# Epoch 00005: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 6/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 47.8367 - vae_r_loss: 43.1070 - vae_kl_loss: 4.7297
#
# Epoch 00006: saving model to run/vae/0002_digits/weights/weights-006-47.84.h5
#
# Epoch 00006: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 7/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 47.4996 - vae_r_loss: 42.7218 - vae_kl_loss: 4.7778
#
# Epoch 00007: saving model to run/vae/0002_digits/weights/weights-007-47.50.h5
#
# Epoch 00007: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 8/200
# 60000/60000 [==============================] - 15s 245us/step - loss: 47.2496 - vae_r_loss: 42.4085 - vae_kl_loss: 4.8411
#
# Epoch 00008: saving model to run/vae/0002_digits/weights/weights-008-47.25.h5
#
# Epoch 00008: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 9/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 47.0142 - vae_r_loss: 42.1380 - vae_kl_loss: 4.8762
#
# Epoch 00009: saving model to run/vae/0002_digits/weights/weights-009-47.01.h5
#
# Epoch 00009: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 10/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 46.7737 - vae_r_loss: 41.8511 - vae_kl_loss: 4.9226
#
# Epoch 00010: saving model to run/vae/0002_digits/weights/weights-010-46.77.h5
#
# Epoch 00010: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 11/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 46.5831 - vae_r_loss: 41.6342 - vae_kl_loss: 4.9489
#
# Epoch 00011: saving model to run/vae/0002_digits/weights/weights-011-46.58.h5
#
# Epoch 00011: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 12/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 46.4616 - vae_r_loss: 41.4912 - vae_kl_loss: 4.9704
#
# Epoch 00012: saving model to run/vae/0002_digits/weights/weights-012-46.46.h5
#
# Epoch 00012: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 13/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 46.3051 - vae_r_loss: 41.3040 - vae_kl_loss: 5.0012
#
# Epoch 00013: saving model to run/vae/0002_digits/weights/weights-013-46.31.h5
#
# Epoch 00013: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 14/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 46.1825 - vae_r_loss: 41.1517 - vae_kl_loss: 5.0308
#
# Epoch 00014: saving model to run/vae/0002_digits/weights/weights-014-46.18.h5
#
# Epoch 00014: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 15/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 46.0658 - vae_r_loss: 41.0229 - vae_kl_loss: 5.0429
#
# Epoch 00015: saving model to run/vae/0002_digits/weights/weights-015-46.07.h5
#
# Epoch 00015: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 16/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 45.9621 - vae_r_loss: 40.8972 - vae_kl_loss: 5.0649
#
# Epoch 00016: saving model to run/vae/0002_digits/weights/weights-016-45.96.h5
#
# Epoch 00016: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 17/200
# 60000/60000 [==============================] - 15s 245us/step - loss: 45.8922 - vae_r_loss: 40.8043 - vae_kl_loss: 5.0879
#
# Epoch 00017: saving model to run/vae/0002_digits/weights/weights-017-45.89.h5
#
# Epoch 00017: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 18/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 45.7852 - vae_r_loss: 40.6870 - vae_kl_loss: 5.0981
#
# Epoch 00018: saving model to run/vae/0002_digits/weights/weights-018-45.79.h5
#
# Epoch 00018: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 19/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 45.6787 - vae_r_loss: 40.5673 - vae_kl_loss: 5.1114
#
# Epoch 00019: saving model to run/vae/0002_digits/weights/weights-019-45.68.h5
#
# Epoch 00019: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 20/200
# 60000/60000 [==============================] - 15s 244us/step - loss: 45.6364 - vae_r_loss: 40.5020 - vae_kl_loss: 5.1343
#
# Epoch 00020: saving model to run/vae/0002_digits/weights/weights-020-45.64.h5
#
# Epoch 00020: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 21/200
# 60000/60000 [==============================] - 15s 243us/step - loss: 45.5495 - vae_r_loss: 40.4140 - vae_kl_loss: 5.1355
#
# Epoch 00021: saving model to run/vae/0002_digits/weights/weights-021-45.55.h5
#
# Epoch 00021: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 22/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 45.4740 - vae_r_loss: 40.3329 - vae_kl_loss: 5.1412
#
# Epoch 00022: saving model to run/vae/0002_digits/weights/weights-022-45.47.h5
#
# Epoch 00022: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 23/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 45.3845 - vae_r_loss: 40.2250 - vae_kl_loss: 5.1595
#
# Epoch 00023: saving model to run/vae/0002_digits/weights/weights-023-45.38.h5
#
# Epoch 00023: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 24/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 45.3337 - vae_r_loss: 40.1618 - vae_kl_loss: 5.1719
#
# Epoch 00024: saving model to run/vae/0002_digits/weights/weights-024-45.33.h5
#
# Epoch 00024: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 25/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 45.2746 - vae_r_loss: 40.1025 - vae_kl_loss: 5.1721
#
# Epoch 00025: saving model to run/vae/0002_digits/weights/weights-025-45.27.h5
#
# Epoch 00025: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 26/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 45.2646 - vae_r_loss: 40.0736 - vae_kl_loss: 5.1910
#
# Epoch 00026: saving model to run/vae/0002_digits/weights/weights-026-45.26.h5
#
# Epoch 00026: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 27/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 45.1940 - vae_r_loss: 39.9919 - vae_kl_loss: 5.2021
#
# Epoch 00027: saving model to run/vae/0002_digits/weights/weights-027-45.19.h5
#
# Epoch 00027: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 28/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 45.1197 - vae_r_loss: 39.9070 - vae_kl_loss: 5.2127
#
# Epoch 00028: saving model to run/vae/0002_digits/weights/weights-028-45.12.h5
#
# Epoch 00028: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 29/200
# 60000/60000 [==============================] - 15s 245us/step - loss: 45.0718 - vae_r_loss: 39.8514 - vae_kl_loss: 5.2204
#
# Epoch 00029: saving model to run/vae/0002_digits/weights/weights-029-45.07.h5
#
# Epoch 00029: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 30/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 45.0269 - vae_r_loss: 39.8070 - vae_kl_loss: 5.2199
#
# Epoch 00030: saving model to run/vae/0002_digits/weights/weights-030-45.03.h5
#
# Epoch 00030: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 31/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 44.9999 - vae_r_loss: 39.7726 - vae_kl_loss: 5.2273
#
# Epoch 00031: saving model to run/vae/0002_digits/weights/weights-031-45.00.h5
#
# Epoch 00031: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 32/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 44.9563 - vae_r_loss: 39.7104 - vae_kl_loss: 5.2459
#
# Epoch 00032: saving model to run/vae/0002_digits/weights/weights-032-44.96.h5
#
# Epoch 00032: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 33/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 44.9010 - vae_r_loss: 39.6630 - vae_kl_loss: 5.2379
#
# Epoch 00033: saving model to run/vae/0002_digits/weights/weights-033-44.90.h5
#
# Epoch 00033: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 34/200
# 60000/60000 [==============================] - 15s 242us/step - loss: 44.8974 - vae_r_loss: 39.6494 - vae_kl_loss: 5.2481
#
# Epoch 00034: saving model to run/vae/0002_digits/weights/weights-034-44.90.h5
#
# Epoch 00034: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 35/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 44.8331 - vae_r_loss: 39.5665 - vae_kl_loss: 5.2666
#
# Epoch 00035: saving model to run/vae/0002_digits/weights/weights-035-44.83.h5
#
# Epoch 00035: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 36/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 44.7990 - vae_r_loss: 39.5252 - vae_kl_loss: 5.2738
#
# Epoch 00036: saving model to run/vae/0002_digits/weights/weights-036-44.80.h5
#
# Epoch 00036: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 37/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 44.7493 - vae_r_loss: 39.4820 - vae_kl_loss: 5.2674
#
# Epoch 00037: saving model to run/vae/0002_digits/weights/weights-037-44.75.h5
#
# Epoch 00037: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 38/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 44.7165 - vae_r_loss: 39.4379 - vae_kl_loss: 5.2785
#
# Epoch 00038: saving model to run/vae/0002_digits/weights/weights-038-44.72.h5
#
# Epoch 00038: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 39/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 44.6851 - vae_r_loss: 39.3986 - vae_kl_loss: 5.2864
#
# Epoch 00039: saving model to run/vae/0002_digits/weights/weights-039-44.69.h5
#
# Epoch 00039: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 40/200
# 60000/60000 [==============================] - 15s 258us/step - loss: 44.6458 - vae_r_loss: 39.3442 - vae_kl_loss: 5.3016
#
# Epoch 00040: saving model to run/vae/0002_digits/weights/weights-040-44.65.h5
#
# Epoch 00040: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 41/200
# 60000/60000 [==============================] - 15s 245us/step - loss: 44.6288 - vae_r_loss: 39.3302 - vae_kl_loss: 5.2987
#
# Epoch 00041: saving model to run/vae/0002_digits/weights/weights-041-44.63.h5
#
# Epoch 00041: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 42/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 44.6021 - vae_r_loss: 39.3097 - vae_kl_loss: 5.2925
#
# Epoch 00042: saving model to run/vae/0002_digits/weights/weights-042-44.60.h5
#
# Epoch 00042: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 43/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 44.5576 - vae_r_loss: 39.2420 - vae_kl_loss: 5.3156
#
# Epoch 00043: saving model to run/vae/0002_digits/weights/weights-043-44.56.h5
#
# Epoch 00043: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 44/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 44.5363 - vae_r_loss: 39.2210 - vae_kl_loss: 5.3153
#
# Epoch 00044: saving model to run/vae/0002_digits/weights/weights-044-44.54.h5
#
# Epoch 00044: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 45/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 44.5228 - vae_r_loss: 39.2126 - vae_kl_loss: 5.3102
#
# Epoch 00045: saving model to run/vae/0002_digits/weights/weights-045-44.52.h5
#
# Epoch 00045: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 46/200
# 60000/60000 [==============================] - 15s 243us/step - loss: 44.4976 - vae_r_loss: 39.1677 - vae_kl_loss: 5.3299
#
# Epoch 00046: saving model to run/vae/0002_digits/weights/weights-046-44.50.h5
#
# Epoch 00046: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 47/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 44.4312 - vae_r_loss: 39.0977 - vae_kl_loss: 5.3335
#
# Epoch 00047: saving model to run/vae/0002_digits/weights/weights-047-44.43.h5
#
# Epoch 00047: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 48/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 44.4256 - vae_r_loss: 39.0990 - vae_kl_loss: 5.3266
#
# Epoch 00048: saving model to run/vae/0002_digits/weights/weights-048-44.43.h5
#
# Epoch 00048: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 49/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 44.3706 - vae_r_loss: 39.0467 - vae_kl_loss: 5.3239
#
# Epoch 00049: saving model to run/vae/0002_digits/weights/weights-049-44.37.h5
#
# Epoch 00049: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 50/200
# 60000/60000 [==============================] - 15s 245us/step - loss: 44.3810 - vae_r_loss: 39.0435 - vae_kl_loss: 5.3375
#
# Epoch 00050: saving model to run/vae/0002_digits/weights/weights-050-44.38.h5
#
# Epoch 00050: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 51/200
# 60000/60000 [==============================] - 15s 243us/step - loss: 44.3568 - vae_r_loss: 39.0115 - vae_kl_loss: 5.3453
#
# Epoch 00051: saving model to run/vae/0002_digits/weights/weights-051-44.36.h5
#
# Epoch 00051: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 52/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 44.3430 - vae_r_loss: 38.9987 - vae_kl_loss: 5.3444
#
# Epoch 00052: saving model to run/vae/0002_digits/weights/weights-052-44.34.h5
#
# Epoch 00052: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 53/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 44.3368 - vae_r_loss: 38.9867 - vae_kl_loss: 5.3502
#
# Epoch 00053: saving model to run/vae/0002_digits/weights/weights-053-44.34.h5
#
# Epoch 00053: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 54/200
# 60000/60000 [==============================] - 14s 240us/step - loss: 44.2983 - vae_r_loss: 38.9475 - vae_kl_loss: 5.3509
#
# Epoch 00054: saving model to run/vae/0002_digits/weights/weights-054-44.30.h5
#
# Epoch 00054: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 55/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 44.2442 - vae_r_loss: 38.9023 - vae_kl_loss: 5.3418
#
# Epoch 00055: saving model to run/vae/0002_digits/weights/weights-055-44.24.h5
#
# Epoch 00055: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 56/200
# 60000/60000 [==============================] - 14s 239us/step - loss: 44.2329 - vae_r_loss: 38.8623 - vae_kl_loss: 5.3707
#
# Epoch 00056: saving model to run/vae/0002_digits/weights/weights-056-44.23.h5
#
# Epoch 00056: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 57/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 44.2305 - vae_r_loss: 38.8644 - vae_kl_loss: 5.3661
#
# Epoch 00057: saving model to run/vae/0002_digits/weights/weights-057-44.23.h5
#
# Epoch 00057: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 58/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 44.1844 - vae_r_loss: 38.8177 - vae_kl_loss: 5.3667
#
# Epoch 00058: saving model to run/vae/0002_digits/weights/weights-058-44.18.h5
#
# Epoch 00058: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 59/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 44.1425 - vae_r_loss: 38.7774 - vae_kl_loss: 5.3651
#
# Epoch 00059: saving model to run/vae/0002_digits/weights/weights-059-44.14.h5
#
# Epoch 00059: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 60/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 44.1506 - vae_r_loss: 38.7810 - vae_kl_loss: 5.3695
#
# Epoch 00060: saving model to run/vae/0002_digits/weights/weights-060-44.15.h5
#
# Epoch 00060: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 61/200
# 60000/60000 [==============================] - 15s 242us/step - loss: 44.1448 - vae_r_loss: 38.7583 - vae_kl_loss: 5.3865
#
# Epoch 00061: saving model to run/vae/0002_digits/weights/weights-061-44.14.h5
#
# Epoch 00061: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 62/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 44.1351 - vae_r_loss: 38.7406 - vae_kl_loss: 5.3945
#
# Epoch 00062: saving model to run/vae/0002_digits/weights/weights-062-44.14.h5
#
# Epoch 00062: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 63/200
# 60000/60000 [==============================] - 14s 240us/step - loss: 44.1367 - vae_r_loss: 38.7493 - vae_kl_loss: 5.3874
#
# Epoch 00063: saving model to run/vae/0002_digits/weights/weights-063-44.14.h5
#
# Epoch 00063: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 64/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 44.0473 - vae_r_loss: 38.6660 - vae_kl_loss: 5.3813
#
# Epoch 00064: saving model to run/vae/0002_digits/weights/weights-064-44.05.h5
#
# Epoch 00064: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 65/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 44.0433 - vae_r_loss: 38.6674 - vae_kl_loss: 5.3759
#
# Epoch 00065: saving model to run/vae/0002_digits/weights/weights-065-44.04.h5
#
# Epoch 00065: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 66/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 44.0259 - vae_r_loss: 38.6426 - vae_kl_loss: 5.3833
#
# Epoch 00066: saving model to run/vae/0002_digits/weights/weights-066-44.03.h5
#
# Epoch 00066: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 67/200
# 60000/60000 [==============================] - 14s 240us/step - loss: 44.0302 - vae_r_loss: 38.6319 - vae_kl_loss: 5.3983
#
# Epoch 00067: saving model to run/vae/0002_digits/weights/weights-067-44.03.h5
#
# Epoch 00067: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 68/200
# 60000/60000 [==============================] - 14s 240us/step - loss: 43.9892 - vae_r_loss: 38.5988 - vae_kl_loss: 5.3905
#
# Epoch 00068: saving model to run/vae/0002_digits/weights/weights-068-43.99.h5
#
# Epoch 00068: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 69/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 44.0030 - vae_r_loss: 38.6040 - vae_kl_loss: 5.3990
#
# Epoch 00069: saving model to run/vae/0002_digits/weights/weights-069-44.00.h5
#
# Epoch 00069: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 70/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 43.9390 - vae_r_loss: 38.5405 - vae_kl_loss: 5.3985
#
# Epoch 00070: saving model to run/vae/0002_digits/weights/weights-070-43.94.h5
#
# Epoch 00070: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 71/200
# 60000/60000 [==============================] - 14s 240us/step - loss: 43.9986 - vae_r_loss: 38.5816 - vae_kl_loss: 5.4169
#
# Epoch 00071: saving model to run/vae/0002_digits/weights/weights-071-44.00.h5
#
# Epoch 00071: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 72/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.9348 - vae_r_loss: 38.5018 - vae_kl_loss: 5.4331
#
# Epoch 00072: saving model to run/vae/0002_digits/weights/weights-072-43.93.h5
#
# Epoch 00072: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 73/200
# 60000/60000 [==============================] - 15s 244us/step - loss: 43.9244 - vae_r_loss: 38.5202 - vae_kl_loss: 5.4042
#
# Epoch 00073: saving model to run/vae/0002_digits/weights/weights-073-43.92.h5
#
# Epoch 00073: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 74/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.9534 - vae_r_loss: 38.5303 - vae_kl_loss: 5.4231
#
# Epoch 00074: saving model to run/vae/0002_digits/weights/weights-074-43.95.h5
#
# Epoch 00074: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 75/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.9034 - vae_r_loss: 38.4813 - vae_kl_loss: 5.4221
#
# Epoch 00075: saving model to run/vae/0002_digits/weights/weights-075-43.90.h5
#
# Epoch 00075: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 76/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.8554 - vae_r_loss: 38.4263 - vae_kl_loss: 5.4292
#
# Epoch 00076: saving model to run/vae/0002_digits/weights/weights-076-43.86.h5
#
# Epoch 00076: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 77/200
# 60000/60000 [==============================] - 15s 255us/step - loss: 43.8744 - vae_r_loss: 38.4467 - vae_kl_loss: 5.4276
#
# Epoch 00077: saving model to run/vae/0002_digits/weights/weights-077-43.87.h5
#
# Epoch 00077: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 78/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.8700 - vae_r_loss: 38.4407 - vae_kl_loss: 5.4292
#
# Epoch 00078: saving model to run/vae/0002_digits/weights/weights-078-43.87.h5
#
# Epoch 00078: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 79/200
# 60000/60000 [==============================] - 15s 257us/step - loss: 43.8408 - vae_r_loss: 38.4158 - vae_kl_loss: 5.4250
#
# Epoch 00079: saving model to run/vae/0002_digits/weights/weights-079-43.84.h5
#
# Epoch 00079: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 80/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.8431 - vae_r_loss: 38.4188 - vae_kl_loss: 5.4243
#
# Epoch 00080: saving model to run/vae/0002_digits/weights/weights-080-43.84.h5
#
# Epoch 00080: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 81/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.7923 - vae_r_loss: 38.3600 - vae_kl_loss: 5.4323
#
# Epoch 00081: saving model to run/vae/0002_digits/weights/weights-081-43.79.h5
#
# Epoch 00081: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 82/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.8117 - vae_r_loss: 38.3897 - vae_kl_loss: 5.4220
#
# Epoch 00082: saving model to run/vae/0002_digits/weights/weights-082-43.81.h5
#
# Epoch 00082: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 83/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.7614 - vae_r_loss: 38.3162 - vae_kl_loss: 5.4452
#
# Epoch 00083: saving model to run/vae/0002_digits/weights/weights-083-43.76.h5
#
# Epoch 00083: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 84/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.8148 - vae_r_loss: 38.3771 - vae_kl_loss: 5.4377
#
# Epoch 00084: saving model to run/vae/0002_digits/weights/weights-084-43.81.h5
#
# Epoch 00084: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 85/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.7762 - vae_r_loss: 38.3376 - vae_kl_loss: 5.4386
#
# Epoch 00085: saving model to run/vae/0002_digits/weights/weights-085-43.78.h5
#
# Epoch 00085: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 86/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.7366 - vae_r_loss: 38.2960 - vae_kl_loss: 5.4407
#
# Epoch 00086: saving model to run/vae/0002_digits/weights/weights-086-43.74.h5
#
# Epoch 00086: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 87/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.7188 - vae_r_loss: 38.2693 - vae_kl_loss: 5.4495
#
# Epoch 00087: saving model to run/vae/0002_digits/weights/weights-087-43.72.h5
#
# Epoch 00087: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 88/200
# 60000/60000 [==============================] - 15s 257us/step - loss: 43.7112 - vae_r_loss: 38.2683 - vae_kl_loss: 5.4429
#
# Epoch 00088: saving model to run/vae/0002_digits/weights/weights-088-43.71.h5
#
# Epoch 00088: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 89/200
# 60000/60000 [==============================] - 15s 258us/step - loss: 43.7055 - vae_r_loss: 38.2664 - vae_kl_loss: 5.4391
#
# Epoch 00089: saving model to run/vae/0002_digits/weights/weights-089-43.71.h5
#
# Epoch 00089: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 90/200
# 60000/60000 [==============================] - 16s 269us/step - loss: 43.7128 - vae_r_loss: 38.2680 - vae_kl_loss: 5.4448
#
# Epoch 00090: saving model to run/vae/0002_digits/weights/weights-090-43.71.h5
#
# Epoch 00090: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 91/200
# 60000/60000 [==============================] - 16s 260us/step - loss: 43.6834 - vae_r_loss: 38.2290 - vae_kl_loss: 5.4544
#
# Epoch 00091: saving model to run/vae/0002_digits/weights/weights-091-43.68.h5
#
# Epoch 00091: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 92/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.7127 - vae_r_loss: 38.2539 - vae_kl_loss: 5.4588
#
# Epoch 00092: saving model to run/vae/0002_digits/weights/weights-092-43.71.h5
#
# Epoch 00092: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 93/200
# 60000/60000 [==============================] - 15s 257us/step - loss: 43.6617 - vae_r_loss: 38.1958 - vae_kl_loss: 5.4659
#
# Epoch 00093: saving model to run/vae/0002_digits/weights/weights-093-43.66.h5
#
# Epoch 00093: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 94/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.6169 - vae_r_loss: 38.1632 - vae_kl_loss: 5.4536
#
# Epoch 00094: saving model to run/vae/0002_digits/weights/weights-094-43.62.h5
#
# Epoch 00094: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 95/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.6511 - vae_r_loss: 38.1908 - vae_kl_loss: 5.4603
#
# Epoch 00095: saving model to run/vae/0002_digits/weights/weights-095-43.65.h5
#
# Epoch 00095: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 96/200
# 60000/60000 [==============================] - 15s 257us/step - loss: 43.6280 - vae_r_loss: 38.1611 - vae_kl_loss: 5.4669
#
# Epoch 00096: saving model to run/vae/0002_digits/weights/weights-096-43.63.h5
#
# Epoch 00096: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 97/200
# 60000/60000 [==============================] - 15s 255us/step - loss: 43.6593 - vae_r_loss: 38.1988 - vae_kl_loss: 5.4604
#
# Epoch 00097: saving model to run/vae/0002_digits/weights/weights-097-43.66.h5
#
# Epoch 00097: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 98/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.5889 - vae_r_loss: 38.1255 - vae_kl_loss: 5.4634
#
# Epoch 00098: saving model to run/vae/0002_digits/weights/weights-098-43.59.h5
#
# Epoch 00098: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 99/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.5852 - vae_r_loss: 38.1058 - vae_kl_loss: 5.4794
#
# Epoch 00099: saving model to run/vae/0002_digits/weights/weights-099-43.59.h5
#
# Epoch 00099: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 100/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.6017 - vae_r_loss: 38.1291 - vae_kl_loss: 5.4726
#
# Epoch 00100: saving model to run/vae/0002_digits/weights/weights-100-43.60.h5
#
# Epoch 00100: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 101/200
# 60000/60000 [==============================] - 16s 262us/step - loss: 43.5966 - vae_r_loss: 38.1169 - vae_kl_loss: 5.4797
#
# Epoch 00101: saving model to run/vae/0002_digits/weights/weights-101-43.60.h5
#
# Epoch 00101: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 102/200
# 60000/60000 [==============================] - 15s 257us/step - loss: 43.5915 - vae_r_loss: 38.1095 - vae_kl_loss: 5.4821
#
# Epoch 00102: saving model to run/vae/0002_digits/weights/weights-102-43.59.h5
#
# Epoch 00102: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 103/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.5446 - vae_r_loss: 38.0721 - vae_kl_loss: 5.4725
#
# Epoch 00103: saving model to run/vae/0002_digits/weights/weights-103-43.54.h5
#
# Epoch 00103: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 104/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.5446 - vae_r_loss: 38.0902 - vae_kl_loss: 5.4544
#
# Epoch 00104: saving model to run/vae/0002_digits/weights/weights-104-43.54.h5
#
# Epoch 00104: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 105/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.5448 - vae_r_loss: 38.0672 - vae_kl_loss: 5.4776
#
# Epoch 00105: saving model to run/vae/0002_digits/weights/weights-105-43.54.h5
#
# Epoch 00105: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 106/200
# 60000/60000 [==============================] - 16s 259us/step - loss: 43.5071 - vae_r_loss: 38.0391 - vae_kl_loss: 5.4680
#
# Epoch 00106: saving model to run/vae/0002_digits/weights/weights-106-43.51.h5
#
# Epoch 00106: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 107/200
# 60000/60000 [==============================] - 15s 245us/step - loss: 43.5343 - vae_r_loss: 38.0474 - vae_kl_loss: 5.4868
#
# Epoch 00107: saving model to run/vae/0002_digits/weights/weights-107-43.53.h5
#
# Epoch 00107: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 108/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.5085 - vae_r_loss: 38.0318 - vae_kl_loss: 5.4768
#
# Epoch 00108: saving model to run/vae/0002_digits/weights/weights-108-43.51.h5
#
# Epoch 00108: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 109/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 43.4916 - vae_r_loss: 38.0183 - vae_kl_loss: 5.4733
#
# Epoch 00109: saving model to run/vae/0002_digits/weights/weights-109-43.49.h5
#
# Epoch 00109: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 110/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 43.4815 - vae_r_loss: 37.9988 - vae_kl_loss: 5.4828
#
# Epoch 00110: saving model to run/vae/0002_digits/weights/weights-110-43.48.h5
#
# Epoch 00110: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 111/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.4551 - vae_r_loss: 37.9716 - vae_kl_loss: 5.4835
#
# Epoch 00111: saving model to run/vae/0002_digits/weights/weights-111-43.46.h5
#
# Epoch 00111: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 112/200
# 60000/60000 [==============================] - 15s 243us/step - loss: 43.4568 - vae_r_loss: 37.9818 - vae_kl_loss: 5.4751
#
# Epoch 00112: saving model to run/vae/0002_digits/weights/weights-112-43.46.h5
#
# Epoch 00112: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 113/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.4657 - vae_r_loss: 37.9782 - vae_kl_loss: 5.4875
#
# Epoch 00113: saving model to run/vae/0002_digits/weights/weights-113-43.47.h5
#
# Epoch 00113: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 114/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 43.4772 - vae_r_loss: 37.9847 - vae_kl_loss: 5.4925
#
# Epoch 00114: saving model to run/vae/0002_digits/weights/weights-114-43.48.h5
#
# Epoch 00114: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 115/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.4783 - vae_r_loss: 37.9864 - vae_kl_loss: 5.4919
#
# Epoch 00115: saving model to run/vae/0002_digits/weights/weights-115-43.48.h5
#
# Epoch 00115: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 116/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.4557 - vae_r_loss: 37.9686 - vae_kl_loss: 5.4871
#
# Epoch 00116: saving model to run/vae/0002_digits/weights/weights-116-43.46.h5
#
# Epoch 00116: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 117/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.4389 - vae_r_loss: 37.9364 - vae_kl_loss: 5.5026
#
# Epoch 00117: saving model to run/vae/0002_digits/weights/weights-117-43.44.h5
#
# Epoch 00117: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 118/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.4581 - vae_r_loss: 37.9702 - vae_kl_loss: 5.4879
#
# Epoch 00118: saving model to run/vae/0002_digits/weights/weights-118-43.46.h5
#
# Epoch 00118: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 119/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.4190 - vae_r_loss: 37.9303 - vae_kl_loss: 5.4887
#
# Epoch 00119: saving model to run/vae/0002_digits/weights/weights-119-43.42.h5
#
# Epoch 00119: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 120/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.4209 - vae_r_loss: 37.9099 - vae_kl_loss: 5.5110
#
# Epoch 00120: saving model to run/vae/0002_digits/weights/weights-120-43.42.h5
#
# Epoch 00120: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 121/200
# 60000/60000 [==============================] - 15s 255us/step - loss: 43.3957 - vae_r_loss: 37.9055 - vae_kl_loss: 5.4902
#
# Epoch 00121: saving model to run/vae/0002_digits/weights/weights-121-43.40.h5
#
# Epoch 00121: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 122/200
# 60000/60000 [==============================] - 16s 261us/step - loss: 43.4272 - vae_r_loss: 37.9203 - vae_kl_loss: 5.5068
#
# Epoch 00122: saving model to run/vae/0002_digits/weights/weights-122-43.43.h5
#
# Epoch 00122: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 123/200
# 60000/60000 [==============================] - 15s 255us/step - loss: 43.3668 - vae_r_loss: 37.8678 - vae_kl_loss: 5.4990
#
# Epoch 00123: saving model to run/vae/0002_digits/weights/weights-123-43.37.h5
#
# Epoch 00123: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 124/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.3743 - vae_r_loss: 37.8710 - vae_kl_loss: 5.5033
#
# Epoch 00124: saving model to run/vae/0002_digits/weights/weights-124-43.37.h5
#
# Epoch 00124: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 125/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 43.3797 - vae_r_loss: 37.8702 - vae_kl_loss: 5.5096
#
# Epoch 00125: saving model to run/vae/0002_digits/weights/weights-125-43.38.h5
#
# Epoch 00125: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 126/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.3644 - vae_r_loss: 37.8563 - vae_kl_loss: 5.5081
#
# Epoch 00126: saving model to run/vae/0002_digits/weights/weights-126-43.36.h5
#
# Epoch 00126: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 127/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.3815 - vae_r_loss: 37.8699 - vae_kl_loss: 5.5116
#
# Epoch 00127: saving model to run/vae/0002_digits/weights/weights-127-43.38.h5
#
# Epoch 00127: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 128/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.3751 - vae_r_loss: 37.8669 - vae_kl_loss: 5.5083
#
# Epoch 00128: saving model to run/vae/0002_digits/weights/weights-128-43.38.h5
#
# Epoch 00128: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 129/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.3487 - vae_r_loss: 37.8446 - vae_kl_loss: 5.5041
#
# Epoch 00129: saving model to run/vae/0002_digits/weights/weights-129-43.35.h5
#
# Epoch 00129: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 130/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.3452 - vae_r_loss: 37.8368 - vae_kl_loss: 5.5083
#
# Epoch 00130: saving model to run/vae/0002_digits/weights/weights-130-43.35.h5
#
# Epoch 00130: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 131/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.3379 - vae_r_loss: 37.8084 - vae_kl_loss: 5.5295
#
# Epoch 00131: saving model to run/vae/0002_digits/weights/weights-131-43.34.h5
#
# Epoch 00131: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 132/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.3375 - vae_r_loss: 37.8202 - vae_kl_loss: 5.5173
#
# Epoch 00132: saving model to run/vae/0002_digits/weights/weights-132-43.34.h5
#
# Epoch 00132: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 133/200
# 60000/60000 [==============================] - 16s 261us/step - loss: 43.3262 - vae_r_loss: 37.8016 - vae_kl_loss: 5.5246
#
# Epoch 00133: saving model to run/vae/0002_digits/weights/weights-133-43.33.h5
#
# Epoch 00133: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 134/200
# 60000/60000 [==============================] - 16s 261us/step - loss: 43.3132 - vae_r_loss: 37.7930 - vae_kl_loss: 5.5202
#
# Epoch 00134: saving model to run/vae/0002_digits/weights/weights-134-43.31.h5
#
# Epoch 00134: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 135/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.3153 - vae_r_loss: 37.7991 - vae_kl_loss: 5.5162
#
# Epoch 00135: saving model to run/vae/0002_digits/weights/weights-135-43.32.h5
#
# Epoch 00135: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 136/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.2978 - vae_r_loss: 37.7810 - vae_kl_loss: 5.5168
#
# Epoch 00136: saving model to run/vae/0002_digits/weights/weights-136-43.30.h5
#
# Epoch 00136: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 137/200
# 60000/60000 [==============================] - 16s 261us/step - loss: 43.3061 - vae_r_loss: 37.8010 - vae_kl_loss: 5.5051
#
# Epoch 00137: saving model to run/vae/0002_digits/weights/weights-137-43.31.h5
#
# Epoch 00137: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 138/200
# 60000/60000 [==============================] - 16s 262us/step - loss: 43.2793 - vae_r_loss: 37.7632 - vae_kl_loss: 5.5161
#
# Epoch 00138: saving model to run/vae/0002_digits/weights/weights-138-43.28.h5
#
# Epoch 00138: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 139/200
# 60000/60000 [==============================] - 16s 262us/step - loss: 43.2930 - vae_r_loss: 37.7714 - vae_kl_loss: 5.5216
#
# Epoch 00139: saving model to run/vae/0002_digits/weights/weights-139-43.29.h5
#
# Epoch 00139: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 140/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.2656 - vae_r_loss: 37.7371 - vae_kl_loss: 5.5285
#
# Epoch 00140: saving model to run/vae/0002_digits/weights/weights-140-43.27.h5
#
# Epoch 00140: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 141/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.2809 - vae_r_loss: 37.7574 - vae_kl_loss: 5.5235
#
# Epoch 00141: saving model to run/vae/0002_digits/weights/weights-141-43.28.h5
#
# Epoch 00141: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 142/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.2552 - vae_r_loss: 37.7445 - vae_kl_loss: 5.5107
#
# Epoch 00142: saving model to run/vae/0002_digits/weights/weights-142-43.26.h5
#
# Epoch 00142: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 143/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.2816 - vae_r_loss: 37.7605 - vae_kl_loss: 5.5211
#
# Epoch 00143: saving model to run/vae/0002_digits/weights/weights-143-43.28.h5
#
# Epoch 00143: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 144/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.2469 - vae_r_loss: 37.7245 - vae_kl_loss: 5.5224
#
# Epoch 00144: saving model to run/vae/0002_digits/weights/weights-144-43.25.h5
#
# Epoch 00144: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 145/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 43.2377 - vae_r_loss: 37.7070 - vae_kl_loss: 5.5308
#
# Epoch 00145: saving model to run/vae/0002_digits/weights/weights-145-43.24.h5
#
# Epoch 00145: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 146/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.2444 - vae_r_loss: 37.7185 - vae_kl_loss: 5.5259
#
# Epoch 00146: saving model to run/vae/0002_digits/weights/weights-146-43.24.h5
#
# Epoch 00146: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 147/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.2084 - vae_r_loss: 37.6666 - vae_kl_loss: 5.5419
#
# Epoch 00147: saving model to run/vae/0002_digits/weights/weights-147-43.21.h5
#
# Epoch 00147: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 148/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.2321 - vae_r_loss: 37.6931 - vae_kl_loss: 5.5390
#
# Epoch 00148: saving model to run/vae/0002_digits/weights/weights-148-43.23.h5
#
# Epoch 00148: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 149/200
# 60000/60000 [==============================] - 15s 258us/step - loss: 43.2082 - vae_r_loss: 37.6812 - vae_kl_loss: 5.5270
#
# Epoch 00149: saving model to run/vae/0002_digits/weights/weights-149-43.21.h5
#
# Epoch 00149: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 150/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.2036 - vae_r_loss: 37.6778 - vae_kl_loss: 5.5259
#
# Epoch 00150: saving model to run/vae/0002_digits/weights/weights-150-43.20.h5
#
# Epoch 00150: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 151/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.2181 - vae_r_loss: 37.6937 - vae_kl_loss: 5.5244
#
# Epoch 00151: saving model to run/vae/0002_digits/weights/weights-151-43.22.h5
#
# Epoch 00151: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 152/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.1785 - vae_r_loss: 37.6518 - vae_kl_loss: 5.5267
#
# Epoch 00152: saving model to run/vae/0002_digits/weights/weights-152-43.18.h5
#
# Epoch 00152: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 153/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.2013 - vae_r_loss: 37.6717 - vae_kl_loss: 5.5295
#
# Epoch 00153: saving model to run/vae/0002_digits/weights/weights-153-43.20.h5
#
# Epoch 00153: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 154/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.1938 - vae_r_loss: 37.6638 - vae_kl_loss: 5.5301
#
# Epoch 00154: saving model to run/vae/0002_digits/weights/weights-154-43.19.h5
#
# Epoch 00154: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 155/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.1374 - vae_r_loss: 37.6061 - vae_kl_loss: 5.5313
#
# Epoch 00155: saving model to run/vae/0002_digits/weights/weights-155-43.14.h5
#
# Epoch 00155: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 156/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.1739 - vae_r_loss: 37.6356 - vae_kl_loss: 5.5383
#
# Epoch 00156: saving model to run/vae/0002_digits/weights/weights-156-43.17.h5
#
# Epoch 00156: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 157/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.1375 - vae_r_loss: 37.6043 - vae_kl_loss: 5.5333
#
# Epoch 00157: saving model to run/vae/0002_digits/weights/weights-157-43.14.h5
#
# Epoch 00157: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 158/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.1624 - vae_r_loss: 37.6220 - vae_kl_loss: 5.5403
#
# Epoch 00158: saving model to run/vae/0002_digits/weights/weights-158-43.16.h5
#
# Epoch 00158: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 159/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 43.1551 - vae_r_loss: 37.6204 - vae_kl_loss: 5.5348
#
# Epoch 00159: saving model to run/vae/0002_digits/weights/weights-159-43.16.h5
#
# Epoch 00159: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 160/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 43.1529 - vae_r_loss: 37.6080 - vae_kl_loss: 5.5449
#
# Epoch 00160: saving model to run/vae/0002_digits/weights/weights-160-43.15.h5
#
# Epoch 00160: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 161/200
# 60000/60000 [==============================] - 15s 247us/step - loss: 43.1318 - vae_r_loss: 37.5859 - vae_kl_loss: 5.5460
#
# Epoch 00161: saving model to run/vae/0002_digits/weights/weights-161-43.13.h5
#
# Epoch 00161: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 162/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.1178 - vae_r_loss: 37.5808 - vae_kl_loss: 5.5370
#
# Epoch 00162: saving model to run/vae/0002_digits/weights/weights-162-43.12.h5
#
# Epoch 00162: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 163/200
# 60000/60000 [==============================] - 15s 255us/step - loss: 43.1274 - vae_r_loss: 37.5846 - vae_kl_loss: 5.5428
#
# Epoch 00163: saving model to run/vae/0002_digits/weights/weights-163-43.13.h5
#
# Epoch 00163: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 164/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.1314 - vae_r_loss: 37.6035 - vae_kl_loss: 5.5279
#
# Epoch 00164: saving model to run/vae/0002_digits/weights/weights-164-43.13.h5
#
# Epoch 00164: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 165/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.1465 - vae_r_loss: 37.6123 - vae_kl_loss: 5.5342
#
# Epoch 00165: saving model to run/vae/0002_digits/weights/weights-165-43.15.h5
#
# Epoch 00165: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 166/200
# 60000/60000 [==============================] - 15s 245us/step - loss: 43.0911 - vae_r_loss: 37.5480 - vae_kl_loss: 5.5431
#
# Epoch 00166: saving model to run/vae/0002_digits/weights/weights-166-43.09.h5
#
# Epoch 00166: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 167/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.0999 - vae_r_loss: 37.5564 - vae_kl_loss: 5.5436
#
# Epoch 00167: saving model to run/vae/0002_digits/weights/weights-167-43.10.h5
#
# Epoch 00167: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 168/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.0799 - vae_r_loss: 37.5313 - vae_kl_loss: 5.5486
#
# Epoch 00168: saving model to run/vae/0002_digits/weights/weights-168-43.08.h5
#
# Epoch 00168: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 169/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.1082 - vae_r_loss: 37.5656 - vae_kl_loss: 5.5426
#
# Epoch 00169: saving model to run/vae/0002_digits/weights/weights-169-43.11.h5
#
# Epoch 00169: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 170/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.1155 - vae_r_loss: 37.5669 - vae_kl_loss: 5.5486
#
# Epoch 00170: saving model to run/vae/0002_digits/weights/weights-170-43.12.h5
#
# Epoch 00170: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 171/200
# 60000/60000 [==============================] - 15s 243us/step - loss: 43.0901 - vae_r_loss: 37.5436 - vae_kl_loss: 5.5465
#
# Epoch 00171: saving model to run/vae/0002_digits/weights/weights-171-43.09.h5
#
# Epoch 00171: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 172/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.1058 - vae_r_loss: 37.5560 - vae_kl_loss: 5.5498
#
# Epoch 00172: saving model to run/vae/0002_digits/weights/weights-172-43.11.h5
#
# Epoch 00172: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 173/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.0903 - vae_r_loss: 37.5379 - vae_kl_loss: 5.5523
#
# Epoch 00173: saving model to run/vae/0002_digits/weights/weights-173-43.09.h5
#
# Epoch 00173: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 174/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.0628 - vae_r_loss: 37.5119 - vae_kl_loss: 5.5509
#
# Epoch 00174: saving model to run/vae/0002_digits/weights/weights-174-43.06.h5
#
# Epoch 00174: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 175/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.0838 - vae_r_loss: 37.5310 - vae_kl_loss: 5.5528
#
# Epoch 00175: saving model to run/vae/0002_digits/weights/weights-175-43.08.h5
#
# Epoch 00175: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 176/200
# 60000/60000 [==============================] - 15s 246us/step - loss: 43.0499 - vae_r_loss: 37.5036 - vae_kl_loss: 5.5463
#
# Epoch 00176: saving model to run/vae/0002_digits/weights/weights-176-43.05.h5
#
# Epoch 00176: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 177/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.0694 - vae_r_loss: 37.5194 - vae_kl_loss: 5.5501
#
# Epoch 00177: saving model to run/vae/0002_digits/weights/weights-177-43.07.h5
#
# Epoch 00177: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 178/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.0589 - vae_r_loss: 37.4893 - vae_kl_loss: 5.5696
#
# Epoch 00178: saving model to run/vae/0002_digits/weights/weights-178-43.06.h5
#
# Epoch 00178: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 179/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.0607 - vae_r_loss: 37.5039 - vae_kl_loss: 5.5569
#
# Epoch 00179: saving model to run/vae/0002_digits/weights/weights-179-43.06.h5
#
# Epoch 00179: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 180/200
# 60000/60000 [==============================] - 15s 257us/step - loss: 43.0877 - vae_r_loss: 37.5201 - vae_kl_loss: 5.5677
#
# Epoch 00180: saving model to run/vae/0002_digits/weights/weights-180-43.09.h5
#
# Epoch 00180: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 181/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 43.0142 - vae_r_loss: 37.4582 - vae_kl_loss: 5.5560
#
# Epoch 00181: saving model to run/vae/0002_digits/weights/weights-181-43.01.h5
#
# Epoch 00181: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 182/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 43.0423 - vae_r_loss: 37.4856 - vae_kl_loss: 5.5568
#
# Epoch 00182: saving model to run/vae/0002_digits/weights/weights-182-43.04.h5
#
# Epoch 00182: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 183/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 43.0349 - vae_r_loss: 37.4721 - vae_kl_loss: 5.5628
#
# Epoch 00183: saving model to run/vae/0002_digits/weights/weights-183-43.03.h5
#
# Epoch 00183: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 184/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.0361 - vae_r_loss: 37.4759 - vae_kl_loss: 5.5601
#
# Epoch 00184: saving model to run/vae/0002_digits/weights/weights-184-43.04.h5
#
# Epoch 00184: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 185/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.0238 - vae_r_loss: 37.4638 - vae_kl_loss: 5.5600
#
# Epoch 00185: saving model to run/vae/0002_digits/weights/weights-185-43.02.h5
#
# Epoch 00185: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 186/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 43.0127 - vae_r_loss: 37.4400 - vae_kl_loss: 5.5728
#
# Epoch 00186: saving model to run/vae/0002_digits/weights/weights-186-43.01.h5
#
# Epoch 00186: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 187/200
# 60000/60000 [==============================] - 15s 253us/step - loss: 43.0190 - vae_r_loss: 37.4541 - vae_kl_loss: 5.5649
#
# Epoch 00187: saving model to run/vae/0002_digits/weights/weights-187-43.02.h5
#
# Epoch 00187: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 188/200
# 60000/60000 [==============================] - 15s 243us/step - loss: 42.9844 - vae_r_loss: 37.4189 - vae_kl_loss: 5.5655
#
# Epoch 00188: saving model to run/vae/0002_digits/weights/weights-188-42.98.h5
#
# Epoch 00188: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 189/200
# 60000/60000 [==============================] - 15s 251us/step - loss: 43.0262 - vae_r_loss: 37.4552 - vae_kl_loss: 5.5710
#
# Epoch 00189: saving model to run/vae/0002_digits/weights/weights-189-43.03.h5
#
# Epoch 00189: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 190/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 43.0089 - vae_r_loss: 37.4417 - vae_kl_loss: 5.5672
#
# Epoch 00190: saving model to run/vae/0002_digits/weights/weights-190-43.01.h5
#
# Epoch 00190: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 191/200
# 60000/60000 [==============================] - 15s 252us/step - loss: 42.9952 - vae_r_loss: 37.4205 - vae_kl_loss: 5.5747
#
# Epoch 00191: saving model to run/vae/0002_digits/weights/weights-191-43.00.h5
#
# Epoch 00191: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 192/200
# 60000/60000 [==============================] - 14s 241us/step - loss: 42.9761 - vae_r_loss: 37.4128 - vae_kl_loss: 5.5633
#
# Epoch 00192: saving model to run/vae/0002_digits/weights/weights-192-42.98.h5
#
# Epoch 00192: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 193/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 42.9933 - vae_r_loss: 37.4313 - vae_kl_loss: 5.5621
#
# Epoch 00193: saving model to run/vae/0002_digits/weights/weights-193-42.99.h5
#
# Epoch 00193: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 194/200
# 60000/60000 [==============================] - 15s 255us/step - loss: 42.9738 - vae_r_loss: 37.4103 - vae_kl_loss: 5.5635
#
# Epoch 00194: saving model to run/vae/0002_digits/weights/weights-194-42.97.h5
#
# Epoch 00194: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 195/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 42.9742 - vae_r_loss: 37.4008 - vae_kl_loss: 5.5733
#
# Epoch 00195: saving model to run/vae/0002_digits/weights/weights-195-42.97.h5
#
# Epoch 00195: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 196/200
# 60000/60000 [==============================] - 15s 254us/step - loss: 42.9901 - vae_r_loss: 37.4231 - vae_kl_loss: 5.5670
#
# Epoch 00196: saving model to run/vae/0002_digits/weights/weights-196-42.99.h5
#
# Epoch 00196: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 197/200
# 60000/60000 [==============================] - 15s 249us/step - loss: 42.9706 - vae_r_loss: 37.4027 - vae_kl_loss: 5.5680
#
# Epoch 00197: saving model to run/vae/0002_digits/weights/weights-197-42.97.h5
#
# Epoch 00197: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 198/200
# 60000/60000 [==============================] - 15s 250us/step - loss: 42.9591 - vae_r_loss: 37.3857 - vae_kl_loss: 5.5735
#
# Epoch 00198: saving model to run/vae/0002_digits/weights/weights-198-42.96.h5
#
# Epoch 00198: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 199/200
# 60000/60000 [==============================] - 15s 248us/step - loss: 42.9412 - vae_r_loss: 37.3767 - vae_kl_loss: 5.5645
#
# Epoch 00199: saving model to run/vae/0002_digits/weights/weights-199-42.94.h5
#
# Epoch 00199: saving model to run/vae/0002_digits/weights/weights.h5
# Epoch 200/200
# 60000/60000 [==============================] - 15s 256us/step - loss: 42.9863 - vae_r_loss: 37.4129 - vae_kl_loss: 5.5734
#
# Epoch 00200: saving model to run/vae/0002_digits/weights/weights-200-42.99.h5
#
# Epoch 00200: saving model to run/vae/0002_digits/weights/weights.h5

# %% [markdown]
# Analysis

# %%
def load_model(model_class, folder):
    
    with open(os.path.join(folder, 'params.pkl'), 'rb') as f:
        params = pickle.load(f)

    model = model_class(*params)

    model.load_weights(os.path.join(folder, 'weights/weights.h5'))

    return model

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

# %%
vae = load_model(VariationalAutoencoder, RUN_FOLDER)

# %% [markdown]
# Reconstructing original paintings

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

z_points = vae.encoder.predict(example_images)

reconst_images = vae.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+1)
    sub.axis('off')
    sub.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=sub.transAxes)
            
    sub.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    sub.axis('off')
    sub.imshow(img, cmap='gray_r')

# %%
n_to_show = 5000
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)
plt.show()

# %% [markdown]
# markers in the latent space and their generated images

# %%
figsize = 8
plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)


grid_size = 15
grid_depth = 2
figsize = 15

x = np.random.normal(size = grid_size * grid_depth)
y = np.random.normal(size = grid_size * grid_depth)

z_grid = np.array(list(zip(x, y)))
reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=8, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %% [markdown]
# colored plot of the latent space

# %%
from scipy.stats import norm

# %%
n_to_show = 5000
grid_size = 15
fig_height = 7
fig_width = 15

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)
p_points = norm.cdf(z_points)

fig = plt.figure(figsize=(fig_width, fig_height))

ax = fig.add_subplot(1, 2, 1)
plot_1 = ax.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar(plot_1)

ax = fig.add_subplot(1, 2, 2)
plot_2 = ax.scatter(p_points[:, 0] , p_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=5)



plt.show()

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

x = norm.ppf(np.linspace(0.01, 0.99, grid_size))
y = norm.ppf(np.linspace(0.01, 0.99, grid_size))
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=2)




plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
